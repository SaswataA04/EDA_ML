# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
df = pd.read_csv('encoding_practice_dataset.csv')

# %%
df.select_dtypes(include='object').columns
#df.select_dtypes(include='object').columns
#this step is optional for small dataseta but for bigger datasets , its needed to know the nature of cilumn
# Out:
# Index(['user_id', 'gender', 'education_level', 'job_role', 'city',
#        'marital_status', 'device_type', 'subscription_plan', 'payment_method'],
#       dtype='object')

# %%
le = LabelEncoder()

# %%
df['education_level'] = le.fit_transform(df['education_level'])

# %%
df
# Out:
#     user_id  gender  education_level    job_role     city marital_status  \
# 0        U1    Male                2       Sales  City_38       Divorced
# 1        U2  Female                0      Doctor  City_18        Married
# 2        U3  Female                3       Sales  City_26        Married
# 3        U4  Female                0  Consultant   City_6        Widowed
# 4        U5    Male                3          HR   City_4       Divorced
# ..      ...     ...              ...         ...      ...            ...
# 995    U996    Male                0  Technician  City_11       Divorced
# 996    U997  Female                4     Teacher  City_32       Divorced
# 997    U998    Male                2      Doctor  City_11         Single
# 998    U999  Female                2       Sales  City_18         Single
# 999   U1000    Male                1       Sales  City_27        Married
#
#     device_type subscription_plan payment_method  monthly_income  \
# 0        Mobile          Standard         Wallet           37784
# 1        Tablet          Standard            UPI          127167
# 2        Tablet              Free           Cash           82359
# 3        Mobile          Standard         Wallet           93608
# 4        Laptop           Premium    Net Banking           30111
# ..          ...               ...            ...             ...
# 995      Mobile          Standard    Net Banking          134694
# 996      Tablet          Standard    Credit Card          147631
# 997      Mobile              Free           Cash           65893
# 998      Mobile             Basic    Net Banking           30167
# 999      Tablet              Free         Wallet           53598
#
#      tenure_months  churn
# 0               24      0
# 1               27      0
# 2               37      1
# 3               39      0
# 4               63      0
# ..             ...    ...
# 995             56      0
# 996             59      0
# 997             63      0
# 998             59      1
# 999             51      1
#
# [1000 rows x 12 columns]

# %%
le.classes_
# Out:
# array(['Bachelor', 'Diploma', 'High School', 'Master', 'PhD'],
#       dtype=object)

# %%
df
# Out:
#     user_id  gender  education_level    job_role     city marital_status  \
# 0        U1    Male                2       Sales  City_38       Divorced
# 1        U2  Female                0      Doctor  City_18        Married
# 2        U3  Female                3       Sales  City_26        Married
# 3        U4  Female                0  Consultant   City_6        Widowed
# 4        U5    Male                3          HR   City_4       Divorced
# ..      ...     ...              ...         ...      ...            ...
# 995    U996    Male                0  Technician  City_11       Divorced
# 996    U997  Female                4     Teacher  City_32       Divorced
# 997    U998    Male                2      Doctor  City_11         Single
# 998    U999  Female                2       Sales  City_18         Single
# 999   U1000    Male                1       Sales  City_27        Married
#
#     device_type subscription_plan payment_method  monthly_income  \
# 0        Mobile          Standard         Wallet           37784
# 1        Tablet          Standard            UPI          127167
# 2        Tablet              Free           Cash           82359
# 3        Mobile          Standard         Wallet           93608
# 4        Laptop           Premium    Net Banking           30111
# ..          ...               ...            ...             ...
# 995      Mobile          Standard    Net Banking          134694
# 996      Tablet          Standard    Credit Card          147631
# 997      Mobile              Free           Cash           65893
# 998      Mobile             Basic    Net Banking           30167
# 999      Tablet              Free         Wallet           53598
#
#      tenure_months  churn
# 0               24      0
# 1               27      0
# 2               37      1
# 3               39      0
# 4               63      0
# ..             ...    ...
# 995             56      0
# 996             59      0
# 997             63      0
# 998             59      1
# 999             51      1
#
# [1000 rows x 12 columns]
